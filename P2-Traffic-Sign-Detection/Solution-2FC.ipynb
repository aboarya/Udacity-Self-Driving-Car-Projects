# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission, if necessary. Sections that begin with **'Implementation'** in the header indicate where you should begin your implementation for your project. Note that some sections of implementation are optional, and will be marked with **'Optional'** in the header.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# all imports
import time
import pickle
import csv
import operator
from itertools import groupby
from collections import OrderedDict

import cv2
import numpy as np
import tensorflow as tf
from tensorflow.contrib.layers import flatten

import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline

from utils2layers import *

# %%
training_file = 'train.p'
testing_file = 'test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)

with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

classes = [i for i in range(44)]

X, Y = train['features'], train['labels']

X_test, y_test = test['features'], test['labels']

# %%
names = {}
with open('signnames.csv') as _f:
    rows = csv.reader(_f, delimiter=',')
    next(rows, None)  # skip the headers
    for row in rows:
        names[str(row[0])] = row[1]

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 2D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below.

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
X_train, Y_train, X_val, Y_val = train_test_split(X, Y)

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.
#
# **NOTE:** The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
Y_train = dense_to_one_hot(Y_train, num_classes)

Y_val = dense_to_one_hot(Y_val, num_classes)

Y_test =  dense_to_one_hot(y_test, num_classes)

# %%
# Image Tensor
images_placeholder = tf.placeholder(tf.float32, shape=[None, 32, 32, 3], name='x')

gray = tf.image.rgb_to_grayscale(images_placeholder, name='gray')

gray /= 255.

# Label Tensor
labels_placeholder = tf.placeholder(tf.float32, shape=(None, 43), name='y')

# dropout Tensor
keep_prob = tf.placeholder(tf.float32, name='drop')

# construct model
logits = inference(gray, keep_prob)

# calculate loss
loss_value = loss(logits, labels_placeholder)

# training
train_op = training(loss_value, 0.0001)

# accuracy
acc = accuracy(logits, labels_placeholder)

saver = tf.train.Saver()

# %%
steps = len(X_train) // BATCH_SIZE
    
train_num_examples = steps * BATCH_SIZE

# %%
def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    total_loss = 0
    sess = tf.get_default_session()
    acc_steps = len(X_data) // BATCH_SIZE
    for i in range(acc_steps):
        batch_x, batch_y = next_batch(X_val, Y_val, BATCH_SIZE)
                   
        loss, accuracy = sess.run([loss_value, acc], feed_dict={
                images_placeholder: batch_x,
                labels_placeholder: batch_y,
                keep_prob: 0.5
                })
        total_accuracy += (accuracy * len(batch_x))
        total_loss += (loss * len(batch_x))
    return (total_accuracy / num_examples, total_loss / num_examples)

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    num_examples = len(X_train)
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        for j in range(steps):
            # train for batch_size
            batch_x, batch_y = next_batch(X_train, Y_train, BATCH_SIZE)
            sess.run(train_op, feed_dict={
                images_placeholder: batch_x,
                labels_placeholder: batch_y,
                keep_prob: 0.5})
            
        val_accuracy, val_loss = evaluate(X_val, Y_val)
        print("EPOCH {} ...".format(i+1))
        print("Validation Loss = {:.3f} and Validation Accuracy = {:.3f}".format(val_loss, val_accuracy*100))
        
        # for TensorBoard
        #     summary_op = tf.merge_all_summaries()

        #         summary_writer = tf.train.SummaryWriter("/home/ubuntu/gtsd-summary", sess.graph)
        save_path = saver.save(sess, '/home/ubuntu/gtsd-{}.chkpt'.format(i))
        print("Model saved in file: %s" % save_path)
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Loss = 3.251 and Validation Accuracy = 15.285
# Model saved in file: /home/ubuntu/gtsd-0.chkpt
# EPOCH 2 ...
# Validation Loss = 2.595 and Validation Accuracy = 31.956
# Model saved in file: /home/ubuntu/gtsd-1.chkpt
# EPOCH 3 ...
# Validation Loss = 2.040 and Validation Accuracy = 44.640
# Model saved in file: /home/ubuntu/gtsd-2.chkpt
# EPOCH 4 ...
# Validation Loss = 1.638 and Validation Accuracy = 53.201
# Model saved in file: /home/ubuntu/gtsd-3.chkpt
# EPOCH 5 ...
# Validation Loss = 1.335 and Validation Accuracy = 61.234
# Model saved in file: /home/ubuntu/gtsd-4.chkpt
# EPOCH 6 ...
# Validation Loss = 1.137 and Validation Accuracy = 65.681
# Model saved in file: /home/ubuntu/gtsd-5.chkpt
# EPOCH 7 ...
# Validation Loss = 0.962 and Validation Accuracy = 70.764
# Model saved in file: /home/ubuntu/gtsd-6.chkpt
# EPOCH 8 ...
# Validation Loss = 0.851 and Validation Accuracy = 74.216
# Model saved in file: /home/ubuntu/gtsd-7.chkpt
# EPOCH 9 ...
# Validation Loss = 0.724 and Validation Accuracy = 77.540
# Model saved in file: /home/ubuntu/gtsd-8.chkpt
# EPOCH 10 ...
# Validation Loss = 0.642 and Validation Accuracy = 79.716
# Model saved in file: /home/ubuntu/gtsd-9.chkpt
# EPOCH 11 ...
# Validation Loss = 0.568 and Validation Accuracy = 82.428
# Model saved in file: /home/ubuntu/gtsd-10.chkpt
# EPOCH 12 ...
# Validation Loss = 0.519 and Validation Accuracy = 84.222
# Model saved in file: /home/ubuntu/gtsd-11.chkpt
# EPOCH 13 ...
# Validation Loss = 0.475 and Validation Accuracy = 85.429
# Model saved in file: /home/ubuntu/gtsd-12.chkpt
# EPOCH 14 ...
# Validation Loss = 0.428 and Validation Accuracy = 86.738
# Model saved in file: /home/ubuntu/gtsd-13.chkpt
# EPOCH 15 ...
# Validation Loss = 0.398 and Validation Accuracy = 87.826
# Model saved in file: /home/ubuntu/gtsd-14.chkpt
# EPOCH 16 ...
# Validation Loss = 0.373 and Validation Accuracy = 88.294
# Model saved in file: /home/ubuntu/gtsd-15.chkpt
# EPOCH 17 ...
# Validation Loss = 0.340 and Validation Accuracy = 89.399
# Model saved in file: /home/ubuntu/gtsd-16.chkpt
# EPOCH 18 ...
# Validation Loss = 0.310 and Validation Accuracy = 90.436
# Model saved in file: /home/ubuntu/gtsd-17.chkpt
# EPOCH 19 ...
# Validation Loss = 0.296 and Validation Accuracy = 91.014
# Model saved in file: /home/ubuntu/gtsd-18.chkpt
# EPOCH 20 ...
# Validation Loss = 0.274 and Validation Accuracy = 91.490
# Model saved in file: /home/ubuntu/gtsd-19.chkpt
# EPOCH 21 ...
# Validation Loss = 0.266 and Validation Accuracy = 91.847
# Model saved in file: /home/ubuntu/gtsd-20.chkpt
# EPOCH 22 ...
# Validation Loss = 0.236 and Validation Accuracy = 92.689
# Model saved in file: /home/ubuntu/gtsd-21.chkpt
# EPOCH 23 ...
# Validation Loss = 0.228 and Validation Accuracy = 93.216
# Model saved in file: /home/ubuntu/gtsd-22.chkpt
# EPOCH 24 ...
# Validation Loss = 0.230 and Validation Accuracy = 92.748
# Model saved in file: /home/ubuntu/gtsd-23.chkpt
# EPOCH 25 ...
# Validation Loss = 0.204 and Validation Accuracy = 93.786
# Model saved in file: /home/ubuntu/gtsd-24.chkpt
# EPOCH 26 ...
# Validation Loss = 0.196 and Validation Accuracy = 93.820
# Model saved in file: /home/ubuntu/gtsd-25.chkpt
# EPOCH 27 ...
# Validation Loss = 0.178 and Validation Accuracy = 94.559
# Model saved in file: /home/ubuntu/gtsd-26.chkpt
# EPOCH 28 ...
# Validation Loss = 0.178 and Validation Accuracy = 94.236
# Model saved in file: /home/ubuntu/gtsd-27.chkpt
# EPOCH 29 ...
# Validation Loss = 0.168 and Validation Accuracy = 94.925
# Model saved in file: /home/ubuntu/gtsd-28.chkpt
# EPOCH 30 ...
# Validation Loss = 0.170 and Validation Accuracy = 94.755
# Model saved in file: /home/ubuntu/gtsd-29.chkpt
# EPOCH 31 ...
# Validation Loss = 0.156 and Validation Accuracy = 95.044
# Model saved in file: /home/ubuntu/gtsd-30.chkpt
# EPOCH 32 ...
# Validation Loss = 0.155 and Validation Accuracy = 95.035
# Model saved in file: /home/ubuntu/gtsd-31.chkpt
# EPOCH 33 ...
# Validation Loss = 0.151 and Validation Accuracy = 95.265
# Model saved in file: /home/ubuntu/gtsd-32.chkpt
# EPOCH 34 ...
# Validation Loss = 0.137 and Validation Accuracy = 95.537
# Model saved in file: /home/ubuntu/gtsd-33.chkpt
# EPOCH 35 ...
# Validation Loss = 0.137 and Validation Accuracy = 95.758
# Model saved in file: /home/ubuntu/gtsd-34.chkpt
# EPOCH 36 ...
# Validation Loss = 0.128 and Validation Accuracy = 96.004
# Model saved in file: /home/ubuntu/gtsd-35.chkpt
# EPOCH 37 ...
# Validation Loss = 0.128 and Validation Accuracy = 95.987
# Model saved in file: /home/ubuntu/gtsd-36.chkpt
# EPOCH 38 ...
# Validation Loss = 0.117 and Validation Accuracy = 96.353
# Model saved in file: /home/ubuntu/gtsd-37.chkpt
# EPOCH 39 ...
# Validation Loss = 0.112 and Validation Accuracy = 96.412
# Model saved in file: /home/ubuntu/gtsd-38.chkpt
# EPOCH 40 ...
# Validation Loss = 0.115 and Validation Accuracy = 96.387
# Model saved in file: /home/ubuntu/gtsd-39.chkpt
# EPOCH 41 ...
# Validation Loss = 0.125 and Validation Accuracy = 96.327
# Model saved in file: /home/ubuntu/gtsd-40.chkpt
# EPOCH 42 ...
# Validation Loss = 0.110 and Validation Accuracy = 96.489
# Model saved in file: /home/ubuntu/gtsd-41.chkpt
# EPOCH 43 ...
# Validation Loss = 0.102 and Validation Accuracy = 96.821
# Model saved in file: /home/ubuntu/gtsd-42.chkpt
# EPOCH 44 ...
# Validation Loss = 0.105 and Validation Accuracy = 96.642
# Model saved in file: /home/ubuntu/gtsd-43.chkpt
# EPOCH 45 ...
# Validation Loss = 0.106 and Validation Accuracy = 96.719
# Model saved in file: /home/ubuntu/gtsd-44.chkpt
# EPOCH 46 ...
# Validation Loss = 0.108 and Validation Accuracy = 96.634
# Model saved in file: /home/ubuntu/gtsd-45.chkpt
# EPOCH 47 ...
# Validation Loss = 0.107 and Validation Accuracy = 96.863
# Model saved in file: /home/ubuntu/gtsd-46.chkpt
# EPOCH 48 ...
# Validation Loss = 0.101 and Validation Accuracy = 96.923
# Model saved in file: /home/ubuntu/gtsd-47.chkpt
# EPOCH 49 ...
# Validation Loss = 0.087 and Validation Accuracy = 97.195
# Model saved in file: /home/ubuntu/gtsd-48.chkpt
# EPOCH 50 ...
# Validation Loss = 0.101 and Validation Accuracy = 96.770
# Model saved in file: /home/ubuntu/gtsd-49.chkpt
# EPOCH 51 ...
# Validation Loss = 0.097 and Validation Accuracy = 97.067
# Model saved in file: /home/ubuntu/gtsd-50.chkpt
# EPOCH 52 ...
# Validation Loss = 0.086 and Validation Accuracy = 97.246
# Model saved in file: /home/ubuntu/gtsd-51.chkpt
# EPOCH 53 ...
# Validation Loss = 0.089 and Validation Accuracy = 97.314
# Model saved in file: /home/ubuntu/gtsd-52.chkpt
# EPOCH 54 ...
# Validation Loss = 0.087 and Validation Accuracy = 97.382
# Model saved in file: /home/ubuntu/gtsd-53.chkpt
# EPOCH 55 ...
# Validation Loss = 0.086 and Validation Accuracy = 97.314
# Model saved in file: /home/ubuntu/gtsd-54.chkpt
# EPOCH 56 ...
# Validation Loss = 0.079 and Validation Accuracy = 97.560
# Model saved in file: /home/ubuntu/gtsd-55.chkpt
# EPOCH 57 ...
# Validation Loss = 0.084 and Validation Accuracy = 97.382
# Model saved in file: /home/ubuntu/gtsd-56.chkpt
# EPOCH 58 ...
# Validation Loss = 0.080 and Validation Accuracy = 97.458
# Model saved in file: /home/ubuntu/gtsd-57.chkpt
# EPOCH 59 ...
# Validation Loss = 0.085 and Validation Accuracy = 97.331
# Model saved in file: /home/ubuntu/gtsd-58.chkpt
# EPOCH 60 ...
# Validation Loss = 0.075 and Validation Accuracy = 97.747
# Model saved in file: /home/ubuntu/gtsd-59.chkpt
# EPOCH 61 ...
# Validation Loss = 0.083 and Validation Accuracy = 97.543
# Model saved in file: /home/ubuntu/gtsd-60.chkpt
# EPOCH 62 ...
# Validation Loss = 0.084 and Validation Accuracy = 97.433
# Model saved in file: /home/ubuntu/gtsd-61.chkpt
# EPOCH 63 ...
# Validation Loss = 0.079 and Validation Accuracy = 97.475
# Model saved in file: /home/ubuntu/gtsd-62.chkpt
# EPOCH 64 ...
# Validation Loss = 0.072 and Validation Accuracy = 97.798
# Model saved in file: /home/ubuntu/gtsd-63.chkpt
# EPOCH 65 ...
# Validation Loss = 0.081 and Validation Accuracy = 97.535
# Model saved in file: /home/ubuntu/gtsd-64.chkpt
# EPOCH 66 ...
# Validation Loss = 0.076 and Validation Accuracy = 97.552
# Model saved in file: /home/ubuntu/gtsd-65.chkpt
# EPOCH 67 ...
# Validation Loss = 0.069 and Validation Accuracy = 97.807
# Model saved in file: /home/ubuntu/gtsd-66.chkpt
# EPOCH 68 ...
# Validation Loss = 0.077 and Validation Accuracy = 97.679
# Model saved in file: /home/ubuntu/gtsd-67.chkpt
# EPOCH 69 ...
# Validation Loss = 0.068 and Validation Accuracy = 97.705
# Model saved in file: /home/ubuntu/gtsd-68.chkpt
# EPOCH 70 ...
# Validation Loss = 0.074 and Validation Accuracy = 97.713
# Model saved in file: /home/ubuntu/gtsd-69.chkpt
# EPOCH 71 ...
# Validation Loss = 0.068 and Validation Accuracy = 97.866
# Model saved in file: /home/ubuntu/gtsd-70.chkpt
# EPOCH 72 ...
# Validation Loss = 0.073 and Validation Accuracy = 97.866
# Model saved in file: /home/ubuntu/gtsd-71.chkpt
# EPOCH 73 ...
# Validation Loss = 0.075 and Validation Accuracy = 97.696
# Model saved in file: /home/ubuntu/gtsd-72.chkpt
# EPOCH 74 ...
# Validation Loss = 0.072 and Validation Accuracy = 97.815
# Model saved in file: /home/ubuntu/gtsd-73.chkpt
# EPOCH 75 ...
# Validation Loss = 0.067 and Validation Accuracy = 97.756
# Model saved in file: /home/ubuntu/gtsd-74.chkpt
# EPOCH 76 ...
# Validation Loss = 0.065 and Validation Accuracy = 97.985
# Model saved in file: /home/ubuntu/gtsd-75.chkpt
# EPOCH 77 ...
# Validation Loss = 0.071 and Validation Accuracy = 97.985
# Model saved in file: /home/ubuntu/gtsd-76.chkpt
# EPOCH 78 ...
# Validation Loss = 0.069 and Validation Accuracy = 97.858
# Model saved in file: /home/ubuntu/gtsd-77.chkpt
# EPOCH 79 ...
# Validation Loss = 0.067 and Validation Accuracy = 98.019
# Model saved in file: /home/ubuntu/gtsd-78.chkpt
# EPOCH 80 ...
# Validation Loss = 0.067 and Validation Accuracy = 98.113
# Model saved in file: /home/ubuntu/gtsd-79.chkpt
# EPOCH 81 ...
# Validation Loss = 0.068 and Validation Accuracy = 97.960
# Model saved in file: /home/ubuntu/gtsd-80.chkpt
# EPOCH 82 ...
# Validation Loss = 0.058 and Validation Accuracy = 98.172
# Model saved in file: /home/ubuntu/gtsd-81.chkpt
# EPOCH 83 ...
# Validation Loss = 0.063 and Validation Accuracy = 98.189
# Model saved in file: /home/ubuntu/gtsd-82.chkpt
# EPOCH 84 ...
# Validation Loss = 0.061 and Validation Accuracy = 98.147
# Model saved in file: /home/ubuntu/gtsd-83.chkpt
# EPOCH 85 ...
# Validation Loss = 0.066 and Validation Accuracy = 97.985
# Model saved in file: /home/ubuntu/gtsd-84.chkpt
# EPOCH 86 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.036
# Model saved in file: /home/ubuntu/gtsd-85.chkpt
# EPOCH 87 ...
# Validation Loss = 0.063 and Validation Accuracy = 98.164
# Model saved in file: /home/ubuntu/gtsd-86.chkpt
# EPOCH 88 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.359
# Model saved in file: /home/ubuntu/gtsd-87.chkpt
# EPOCH 89 ...
# Validation Loss = 0.066 and Validation Accuracy = 98.147
# Model saved in file: /home/ubuntu/gtsd-88.chkpt
# EPOCH 90 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.232
# Model saved in file: /home/ubuntu/gtsd-89.chkpt
# EPOCH 91 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.172
# Model saved in file: /home/ubuntu/gtsd-90.chkpt
# EPOCH 92 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.079
# Model saved in file: /home/ubuntu/gtsd-91.chkpt
# EPOCH 93 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.351
# Model saved in file: /home/ubuntu/gtsd-92.chkpt
# EPOCH 94 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.070
# Model saved in file: /home/ubuntu/gtsd-93.chkpt
# EPOCH 95 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.223
# Model saved in file: /home/ubuntu/gtsd-94.chkpt
# EPOCH 96 ...
# Validation Loss = 0.061 and Validation Accuracy = 98.249
# Model saved in file: /home/ubuntu/gtsd-95.chkpt
# EPOCH 97 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.079
# Model saved in file: /home/ubuntu/gtsd-96.chkpt
# EPOCH 98 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.308
# Model saved in file: /home/ubuntu/gtsd-97.chkpt
# EPOCH 99 ...
# Validation Loss = 0.063 and Validation Accuracy = 98.189
# Model saved in file: /home/ubuntu/gtsd-98.chkpt
# EPOCH 100 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.121
# Model saved in file: /home/ubuntu/gtsd-99.chkpt
# EPOCH 101 ...
# Validation Loss = 0.055 and Validation Accuracy = 98.317
# Model saved in file: /home/ubuntu/gtsd-100.chkpt
# EPOCH 102 ...
# Validation Loss = 0.063 and Validation Accuracy = 98.257
# Model saved in file: /home/ubuntu/gtsd-101.chkpt
# EPOCH 103 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.198
# Model saved in file: /home/ubuntu/gtsd-102.chkpt
# EPOCH 104 ...
# Validation Loss = 0.056 and Validation Accuracy = 98.436
# Model saved in file: /home/ubuntu/gtsd-103.chkpt
# EPOCH 105 ...
# Validation Loss = 0.051 and Validation Accuracy = 98.334
# Model saved in file: /home/ubuntu/gtsd-104.chkpt
# EPOCH 106 ...
# Validation Loss = 0.058 and Validation Accuracy = 98.232
# Model saved in file: /home/ubuntu/gtsd-105.chkpt
# EPOCH 107 ...
# Validation Loss = 0.065 and Validation Accuracy = 98.198
# Model saved in file: /home/ubuntu/gtsd-106.chkpt
# EPOCH 108 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.113
# Model saved in file: /home/ubuntu/gtsd-107.chkpt
# EPOCH 109 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.249
# Model saved in file: /home/ubuntu/gtsd-108.chkpt
# EPOCH 110 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.368
# Model saved in file: /home/ubuntu/gtsd-109.chkpt
# EPOCH 111 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.453
# Model saved in file: /home/ubuntu/gtsd-110.chkpt
# EPOCH 112 ...
# Validation Loss = 0.056 and Validation Accuracy = 98.317
# Model saved in file: /home/ubuntu/gtsd-111.chkpt
# EPOCH 113 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.359
# Model saved in file: /home/ubuntu/gtsd-112.chkpt
# EPOCH 114 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.317
# Model saved in file: /home/ubuntu/gtsd-113.chkpt
# EPOCH 115 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.317
# Model saved in file: /home/ubuntu/gtsd-114.chkpt
# EPOCH 116 ...
# Validation Loss = 0.057 and Validation Accuracy = 98.436
# Model saved in file: /home/ubuntu/gtsd-115.chkpt
# EPOCH 117 ...
# Validation Loss = 0.054 and Validation Accuracy = 98.444
# Model saved in file: /home/ubuntu/gtsd-116.chkpt
# EPOCH 118 ...
# Validation Loss = 0.058 and Validation Accuracy = 98.308
# Model saved in file: /home/ubuntu/gtsd-117.chkpt
# EPOCH 119 ...
# Validation Loss = 0.056 and Validation Accuracy = 98.308
# Model saved in file: /home/ubuntu/gtsd-118.chkpt
# EPOCH 120 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.385
# Model saved in file: /home/ubuntu/gtsd-119.chkpt
# EPOCH 121 ...
# Validation Loss = 0.054 and Validation Accuracy = 98.453
# Model saved in file: /home/ubuntu/gtsd-120.chkpt
# EPOCH 122 ...
# Validation Loss = 0.056 and Validation Accuracy = 98.351
# Model saved in file: /home/ubuntu/gtsd-121.chkpt
# EPOCH 123 ...
# Validation Loss = 0.051 and Validation Accuracy = 98.402
# Model saved in file: /home/ubuntu/gtsd-122.chkpt
# EPOCH 124 ...
# Validation Loss = 0.055 and Validation Accuracy = 98.478
# Model saved in file: /home/ubuntu/gtsd-123.chkpt
# EPOCH 125 ...
# Validation Loss = 0.066 and Validation Accuracy = 98.325
# Model saved in file: /home/ubuntu/gtsd-124.chkpt
# EPOCH 126 ...
# Validation Loss = 0.058 and Validation Accuracy = 98.351
# Model saved in file: /home/ubuntu/gtsd-125.chkpt
# EPOCH 127 ...
# Validation Loss = 0.057 and Validation Accuracy = 98.368
# Model saved in file: /home/ubuntu/gtsd-126.chkpt
# EPOCH 128 ...
# Validation Loss = 0.052 and Validation Accuracy = 98.478
# Model saved in file: /home/ubuntu/gtsd-127.chkpt
# EPOCH 129 ...
# Validation Loss = 0.046 and Validation Accuracy = 98.623
# Model saved in file: /home/ubuntu/gtsd-128.chkpt
# EPOCH 130 ...
# Validation Loss = 0.055 and Validation Accuracy = 98.495
# Model saved in file: /home/ubuntu/gtsd-129.chkpt
# EPOCH 131 ...
# Validation Loss = 0.054 and Validation Accuracy = 98.461
# Model saved in file: /home/ubuntu/gtsd-130.chkpt
# EPOCH 132 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.555
# Model saved in file: /home/ubuntu/gtsd-131.chkpt
# EPOCH 133 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.359
# Model saved in file: /home/ubuntu/gtsd-132.chkpt
# EPOCH 134 ...
# Validation Loss = 0.054 and Validation Accuracy = 98.444
# Model saved in file: /home/ubuntu/gtsd-133.chkpt
# EPOCH 135 ...
# Validation Loss = 0.049 and Validation Accuracy = 98.606
# Model saved in file: /home/ubuntu/gtsd-134.chkpt
# EPOCH 136 ...
# Validation Loss = 0.055 and Validation Accuracy = 98.461
# Model saved in file: /home/ubuntu/gtsd-135.chkpt
# EPOCH 137 ...
# Validation Loss = 0.050 and Validation Accuracy = 98.402
# Model saved in file: /home/ubuntu/gtsd-136.chkpt
# EPOCH 138 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.368
# Model saved in file: /home/ubuntu/gtsd-137.chkpt
# EPOCH 139 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.393
# Model saved in file: /home/ubuntu/gtsd-138.chkpt
# EPOCH 140 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.487
# Model saved in file: /home/ubuntu/gtsd-139.chkpt
# EPOCH 141 ...
# Validation Loss = 0.055 and Validation Accuracy = 98.512
# Model saved in file: /home/ubuntu/gtsd-140.chkpt
# EPOCH 142 ...
# Validation Loss = 0.057 and Validation Accuracy = 98.376
# Model saved in file: /home/ubuntu/gtsd-141.chkpt
# EPOCH 143 ...
# Validation Loss = 0.050 and Validation Accuracy = 98.487
# Model saved in file: /home/ubuntu/gtsd-142.chkpt
# EPOCH 144 ...
# Validation Loss = 0.051 and Validation Accuracy = 98.614
# Model saved in file: /home/ubuntu/gtsd-143.chkpt
# EPOCH 145 ...
# Validation Loss = 0.057 and Validation Accuracy = 98.521
# Model saved in file: /home/ubuntu/gtsd-144.chkpt
# EPOCH 146 ...
# Validation Loss = 0.056 and Validation Accuracy = 98.529
# Model saved in file: /home/ubuntu/gtsd-145.chkpt
# EPOCH 147 ...
# Validation Loss = 0.057 and Validation Accuracy = 98.376
# Model saved in file: /home/ubuntu/gtsd-146.chkpt
# EPOCH 148 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.495
# Model saved in file: /home/ubuntu/gtsd-147.chkpt
# EPOCH 149 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.436
# Model saved in file: /home/ubuntu/gtsd-148.chkpt
# EPOCH 150 ...
# Validation Loss = 0.052 and Validation Accuracy = 98.402
# Model saved in file: /home/ubuntu/gtsd-149.chkpt
# EPOCH 151 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.546
# Model saved in file: /home/ubuntu/gtsd-150.chkpt
# EPOCH 152 ...
# Validation Loss = 0.051 and Validation Accuracy = 98.623
# Model saved in file: /home/ubuntu/gtsd-151.chkpt
# EPOCH 153 ...
# Validation Loss = 0.050 and Validation Accuracy = 98.521
# Model saved in file: /home/ubuntu/gtsd-152.chkpt
# EPOCH 154 ...
# Validation Loss = 0.056 and Validation Accuracy = 98.385
# Model saved in file: /home/ubuntu/gtsd-153.chkpt
# EPOCH 155 ...
# Validation Loss = 0.049 and Validation Accuracy = 98.640
# Model saved in file: /home/ubuntu/gtsd-154.chkpt
# EPOCH 156 ...
# Validation Loss = 0.049 and Validation Accuracy = 98.487
# Model saved in file: /home/ubuntu/gtsd-155.chkpt
# EPOCH 157 ...
# Validation Loss = 0.052 and Validation Accuracy = 98.529
# Model saved in file: /home/ubuntu/gtsd-156.chkpt
# EPOCH 158 ...
# Validation Loss = 0.064 and Validation Accuracy = 98.410
# Model saved in file: /home/ubuntu/gtsd-157.chkpt
# EPOCH 159 ...
# Validation Loss = 0.052 and Validation Accuracy = 98.674
# Model saved in file: /home/ubuntu/gtsd-158.chkpt
# EPOCH 160 ...
# Validation Loss = 0.051 and Validation Accuracy = 98.674
# Model saved in file: /home/ubuntu/gtsd-159.chkpt
# EPOCH 161 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.504
# Model saved in file: /home/ubuntu/gtsd-160.chkpt
# EPOCH 162 ...
# Validation Loss = 0.064 and Validation Accuracy = 98.538
# Model saved in file: /home/ubuntu/gtsd-161.chkpt
# EPOCH 163 ...
# Validation Loss = 0.063 and Validation Accuracy = 98.283
# Model saved in file: /home/ubuntu/gtsd-162.chkpt
# EPOCH 164 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.436
# Model saved in file: /home/ubuntu/gtsd-163.chkpt
# EPOCH 165 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.504
# Model saved in file: /home/ubuntu/gtsd-164.chkpt
# EPOCH 166 ...
# Validation Loss = 0.051 and Validation Accuracy = 98.538
# Model saved in file: /home/ubuntu/gtsd-165.chkpt
# EPOCH 167 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.512
# Model saved in file: /home/ubuntu/gtsd-166.chkpt
# EPOCH 168 ...
# Validation Loss = 0.057 and Validation Accuracy = 98.640
# Model saved in file: /home/ubuntu/gtsd-167.chkpt
# EPOCH 169 ...
# Validation Loss = 0.049 and Validation Accuracy = 98.725
# Model saved in file: /home/ubuntu/gtsd-168.chkpt
# EPOCH 170 ...
# Validation Loss = 0.052 and Validation Accuracy = 98.597
# Model saved in file: /home/ubuntu/gtsd-169.chkpt
# EPOCH 171 ...
# Validation Loss = 0.046 and Validation Accuracy = 98.614
# Model saved in file: /home/ubuntu/gtsd-170.chkpt
# EPOCH 172 ...
# Validation Loss = 0.058 and Validation Accuracy = 98.563
# Model saved in file: /home/ubuntu/gtsd-171.chkpt
# EPOCH 173 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.580
# Model saved in file: /home/ubuntu/gtsd-172.chkpt
# EPOCH 174 ...
# Validation Loss = 0.050 and Validation Accuracy = 98.682
# Model saved in file: /home/ubuntu/gtsd-173.chkpt
# EPOCH 175 ...
# Validation Loss = 0.051 and Validation Accuracy = 98.631
# Model saved in file: /home/ubuntu/gtsd-174.chkpt
# EPOCH 176 ...
# Validation Loss = 0.061 and Validation Accuracy = 98.359
# Model saved in file: /home/ubuntu/gtsd-175.chkpt
# EPOCH 177 ...
# Validation Loss = 0.059 and Validation Accuracy = 98.351
# Model saved in file: /home/ubuntu/gtsd-176.chkpt
# EPOCH 178 ...
# Validation Loss = 0.050 and Validation Accuracy = 98.648
# Model saved in file: /home/ubuntu/gtsd-177.chkpt
# EPOCH 179 ...
# Validation Loss = 0.049 and Validation Accuracy = 98.665
# Model saved in file: /home/ubuntu/gtsd-178.chkpt
# EPOCH 180 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.623
# Model saved in file: /home/ubuntu/gtsd-179.chkpt
# EPOCH 181 ...
# Validation Loss = 0.041 and Validation Accuracy = 98.750
# Model saved in file: /home/ubuntu/gtsd-180.chkpt
# EPOCH 182 ...
# Validation Loss = 0.045 and Validation Accuracy = 98.742
# Model saved in file: /home/ubuntu/gtsd-181.chkpt
# EPOCH 183 ...
# Validation Loss = 0.050 and Validation Accuracy = 98.572
# Model saved in file: /home/ubuntu/gtsd-182.chkpt
# EPOCH 184 ...
# Validation Loss = 0.043 and Validation Accuracy = 98.810
# Model saved in file: /home/ubuntu/gtsd-183.chkpt
# EPOCH 185 ...
# Validation Loss = 0.046 and Validation Accuracy = 98.589
# Model saved in file: /home/ubuntu/gtsd-184.chkpt
# EPOCH 186 ...
# Validation Loss = 0.060 and Validation Accuracy = 98.478
# Model saved in file: /home/ubuntu/gtsd-185.chkpt
# EPOCH 187 ...
# Validation Loss = 0.056 and Validation Accuracy = 98.521
# Model saved in file: /home/ubuntu/gtsd-186.chkpt
# EPOCH 188 ...
# Validation Loss = 0.042 and Validation Accuracy = 98.793
# Model saved in file: /home/ubuntu/gtsd-187.chkpt
# EPOCH 189 ...
# Validation Loss = 0.052 and Validation Accuracy = 98.555
# Model saved in file: /home/ubuntu/gtsd-188.chkpt
# EPOCH 190 ...
# Validation Loss = 0.048 and Validation Accuracy = 98.716
# Model saved in file: /home/ubuntu/gtsd-189.chkpt
# EPOCH 191 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.538
# Model saved in file: /home/ubuntu/gtsd-190.chkpt
# EPOCH 192 ...
# Validation Loss = 0.053 and Validation Accuracy = 98.674
# Model saved in file: /home/ubuntu/gtsd-191.chkpt
# EPOCH 193 ...
# Validation Loss = 0.054 and Validation Accuracy = 98.606
# Model saved in file: /home/ubuntu/gtsd-192.chkpt
# EPOCH 194 ...
# Validation Loss = 0.049 and Validation Accuracy = 98.665
# Model saved in file: /home/ubuntu/gtsd-193.chkpt
# EPOCH 195 ...
# Validation Loss = 0.044 and Validation Accuracy = 98.742
# Model saved in file: /home/ubuntu/gtsd-194.chkpt
# EPOCH 196 ...
# Validation Loss = 0.062 and Validation Accuracy = 98.521
# Model saved in file: /home/ubuntu/gtsd-195.chkpt
# EPOCH 197 ...
# Validation Loss = 0.054 and Validation Accuracy = 98.733
# Model saved in file: /home/ubuntu/gtsd-196.chkpt
# EPOCH 198 ...
# Validation Loss = 0.046 and Validation Accuracy = 98.767
# Model saved in file: /home/ubuntu/gtsd-197.chkpt
# EPOCH 199 ...
# Validation Loss = 0.046 and Validation Accuracy = 98.716
# Model saved in file: /home/ubuntu/gtsd-198.chkpt
# EPOCH 200 ...
# Validation Loss = 0.047 and Validation Accuracy = 98.810
# Model saved in file: /home/ubuntu/gtsd-199.chkpt

# %%
with tf.Session() as sess:
    saver.restore(sess, '/home/ubuntu/gtsd-199.chkpt')
    print("Model restored.")
    test_accuracy = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy[0]*100))
# Out:
# Model restored.
# Test Accuracy = 99.018

# %% [markdown]
# ### Question 1
#
# _Describe how you preprocessed the data. Why did you choose that technique?_

# %% [markdown]
# **Answer:**
#
# For preprocessing I explored several options.
#
# 1) Using RGB
#
# Using RGB only yielded a 70% or so validation accuracy
#
# 2) Using YUV
#
# Many of the images are very dark.  I converted the images to YUV and brightened the Y channel but using this same model I was only able to get 88% validation accuracy
#
# 3) Just Grayscaling
#
# With the above model and just grayscaling I saw the highest validation accuracy of 93%
#
# All images were of course normalized to reduce computational by dividing each pixel by the value `255`.

# %% [markdown]
# ### Question 2
#
# _Describe how you set up the training, validation and testing data for your model. **Optional**: If you generated additional data, how did you generate the data? Why did you generate the data? What are the differences in the new dataset (with generated data) from the original dataset?_

# %% [markdown]
# **Answer:**
#
# Having read LeCuN's paper on this task, I decided to Jitter each image in the dataset to account for potential deformations in the test set.  This improved validation accuracy from 86 to 93%.
#
# To create the validation set, I used Sklearn to take 30% of the test set for validation.

# %% [markdown]
# ### Question 3
#
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)  For reference on how to build a deep neural network using TensorFlow, see [Deep Neural Network in TensorFlow
# ](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/b516a270-8600-4f93-a0a3-20dfeabe5da6/concepts/83a3a2a2-a9bd-4b7b-95b0-eb924ab14432) from the classroom._

# %% [markdown]
# **Answer:**
#
#
# I used a very simple model to avoid long training durations.  My model consists of one convolutional layer that is `ReLU` activated and maxpooled, one fully connected layer with `512` neurons and a dropout, and a finaly fully connected layer for classification with `fourty three` neurons; the number of classes.
#
# Full Model details are:
#
# 1) 1st conv 3x3x32
#
# 1.1) 2x2 pooling
#
# 1.2) Stride of 2
#
# 2) output: 32x32x32
#
# 3) FC: 512
#
# 4) dropout : 0.5

# %% [markdown]
# ### Question 4
#
# _How did you train your model? (Type of optimizer, batch size, epochs, hyperparameters, etc.)_
#
# Optimizer: Adam
#
# Epochs: Max of 10000 but I cutt off at 93%
#
# Batch Size: 2500

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 5
#
#
# _What approach did you take in coming up with a solution to this problem? It may have been a process of trial and error, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think this is suitable for the current problem._

# %% [markdown]
# **Answer:**
#
# I began with a trial and error process which is far too involved for a short answer.  After reading the lecture notes for CS231n, the biggest takeaway for me where the forumulas:
#
# `(W−F+2P)/S+1`
#
# and
#
# `P=(F−1)/2`
#
#  Having understood that ConvNets do not fully connect on each layer and only through the depth dimension, I attempted to balance the width and heigths dimensions through the first convolution with a patch of 3, a filter size of 32, a stride of 2, and 2x2 pooling.
#
#  This improved my model drastically.  I still had one other implementation issue:
#
#  I pieced together this code from multiple google searches.  At one point I had code which took the softmax, then a few lines of code later used softmax_with_logits.  While this gave reasonable accuracy of 94% I knew it couldn't be trusted because the loss was not reasonable.
#
#  Removing the `sofmax` and only using `sofmax_with_logits` solved this problem and I consistently received higher than `92%` with this model on each subsequent trial.
#
#  Accuracy on the test set was always above `94.5%` and reached `95.5%` on one trial

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# Take several pictures of traffic signs that you find on the web or around you (at least five), and run them through your classifier on your computer to produce example results. The classifier might not recognize some local signs but it could prove interesting nonetheless.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
import os
from PIL import Image
images = os.listdir('./downloaded-images')
images = [cv2.imread('./downloaded-images/'+img) for img in images]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-a9293c2f4219> in <module>()
#       3 import os
#       4 from PIL import Image
# ----> 5 images = os.listdir('./downloaded-images')
#       6 images = [cv2.imread('./downloaded-images/'+img) for img in images]
#
# FileNotFoundError: [Errno 2] No such file or directory: './downloaded-images'

# %%
fig, axes = plt.subplots(4, 2, figsize=(3, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i], cmap='binary')
    ax.set_xticks([])
    ax.set_yticks([])

# %%
X_test = images
y_test = np.array([19, 40, 39, 14, 16, 10, 3, 31])

# %%
Y_test =  dense_to_one_hot(y_test, num_classes)

# %%
with tf.Session() as sess:
    saver.restore(sess, '/home/ubuntu/gtsd-12-23-16-final.chkpt')
    print("Model restored.")
    test_accuracy = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy[0]*100))

# %% [markdown]
# ### Question 6
#
# _Choose five candidate images of traffic signs and provide them in the report. Are there any particular qualities of the image(s) that might make classification difficult? It could be helpful to plot the images in the notebook._

# %% [markdown]
# **Answer:**

# %%
with tf.Session() as sess:
    saver.restore(sess, '/home/ubuntu/gtsd-12-23-16-final.chkpt')
    print("Model restored.")
    test_accuracy = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy[0]*100))

# %% [markdown]
# ### Question 7
#
# _Is your model able to perform equally well on captured pictures when compared to testing on the dataset? The simplest way to do this check the accuracy of the predictions. For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate._
#
# _**NOTE:** You could check the accuracy manually by using `signnames.csv` (same directory). This file has a mapping from the class id (0-42) to the corresponding sign name. So, you could take the class id the model outputs, lookup the name in `signnames.csv` and see if it matches the sign from the image._

# %% [markdown]
# **Answer:**

# %%
### Visualize the softmax probabilities here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 8
#
# *Use the model's softmax probabilities to visualize the **certainty** of its predictions, [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here. Which predictions is the model certain of? Uncertain? If the model was incorrect in its initial prediction, does the correct prediction appear in the top k? (k should be 5 at most)*
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
